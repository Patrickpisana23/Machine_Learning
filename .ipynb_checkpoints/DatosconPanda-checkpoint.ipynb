# %%
print('Es mi primer programa con la libreria panda')
# Out:
# Es mi primer programa con la libreria panda

# %% [markdown]
# #vamos a programar poco a poco

# %%
import pandas as pd

# %%
series = pd.Series([2,10,20,30,40,50])

# %%
series
# Out:
# 0     2
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 30

# %%
cad = pd.Series(['p', 'l', 'a', 't', 'z', 'i'])

# %%
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
lst = ['Hola', 'mundo', ' robotico']
df = pd.DataFrame(lst)
df
# Out:
#            0
# 0       Hola
# 1      mundo
# 2   robotico

# %%
data = {'Nombre':['Juan', 'Ana', 'Jose', 'Arturo'],  'Edad':[25, 12,  26,  16], 'Pais' : ['MX', 'CO', 'BR', 'MX']}
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad Pais
# 0    Juan    25   MX
# 1     Ana    12   CO
# 2    Jose    26   BR
# 3  Arturo    16   MX

# %%
print(df[['Pais','Edad']])
# Out:
#   Pais  Edad
# 0   MX    25
# 1   CO    12
# 2   BR    26
# 3   MX    16

# %%
data = pd.read_csv('salarios_dc1975e5-393f-4b89-9b04-a2b48ce17388.csv')
data.head(5)
# Out:
#    Aexperiencia  Salario
# 0          10.0    42500
# 1           8.0    36302
# 2           5.4    35000
# 3           2.5    18103
# 4           1.0    15000

# %%
artista = data.Salario

# %%
artista
# Out:
# 0     42500
# 1     36302
# 2     35000
# 3     18103
# 4     15000
# 5     37000
# 6     26300
# 7     35201
# 8     18302
# 9     42000
# 10    27000
# 11    35201
# 12    19201
# 13    28000
# 14    17000
# 15    33402
# 16    19000
# 17    18200
# 18    19000
# 19    17301
# 20    28000
# 21    20000
# 22    27900
# 23    17500
# 24    40000
# 25    42500
# 26    18300
# 27    40000
# 28    25000
# 29    15000
# Name: Salario, dtype: int64

# %%
info = data.iloc[15]
info
# Out:
# Aexperiencia        5.0
# Salario         33402.0
# Name: 15, dtype: float64

# %%
data.tail()
# Out:
#     Aexperiencia  Salario
# 25          10.0    42500
# 26           3.2    18300
# 27          10.0    40000
# 28           4.0    25000
# 29           1.0    15000

# %%
data.shape
# Out:
# (30, 2)

# %%
data.columns
# Out:
# Index(['Aexperiencia', 'Salario'], dtype='object')

# %%
data['Salario'].describe()
# Out:
# count       30.000000
# mean     27107.100000
# std       9458.745839
# min      15000.000000
# 25%      18300.500000
# 50%      26650.000000
# 75%      35201.000000
# max      42500.000000
# Name: Salario, dtype: float64

# %%
data.sort_index(axis= 0, ascending = False)
# Out:
#                        id                               name       artists  \
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# ..                    ...                                ...           ...
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
#
# ...

# %% [markdown]
# # RETO DE PANDA

# %%
data = pd.read_csv('canciones-2018_b2c776e4-1cce-40eb-b3e7-591ea6d29f83.csv')
data.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df = pd.DataFrame(data)

# %%
 df
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
print(df[['key']])
# Out:
#      key
# 0    7.0
# 1    8.0
# 2    5.0
# 3    8.0
# 4    1.0
# ..   ...
# 95  10.0
# 96   3.0
# 97   0.0
# 98  11.0
# 99  11.0
#
# [100 rows x 1 columns]

# %%
data[['name','danceability', 'energy']].sort_index(axis= 0 ,ascending = False)
# Out:
#                                  name  danceability  energy
# 99                         Be Alright         0.553   0.586
# 98        Dusk Till Dawn - Radio Edit         0.258   0.437
# 97                         No Brainer         0.552   0.760
# 96  I Miss You (feat. Julia Michaels)         0.638   0.658
# 95                  Rewrite The Stars         0.684   0.619
# ..                                ...           ...     ...
# 4                      In My Feelings         0.835   0.626
# 3        Psycho (feat. Ty Dolla $ign)         0.739   0.559
# 2          rockstar (feat. 21 Savage)         0.587   0.535
# 1                                SAD!         0.740   0.613
# 0                          God's Plan         0.754   0.449
#
# [100 rows x 3 columns]
