# %% [markdown]
# # vamos con todo

# %% [markdown]
# ## Repaso con panda

# %%
import pandas as pd

# %%
Lista = pd.Series([10,20,30,40,50])

# %%
Lista
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
Lista2 = pd.Series(['Primera', 'Segunda', 'Tercera', 'Cuarta', 'Quinta'])

# %%
Lista2
# Out:
# 0    Primera
# 1    Segunda
# 2    Tercera
# 3     Cuarta
# 4     Quinta
# dtype: object

# %%
Lista2[2]
# Out:
# 'Tercera'

# %%
Lista[2]
# Out:
# 30

# %%
df1 = pd.DataFrame(Lista)

# %%
df1
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
df2 = pd.DataFrame(Lista2)

# %%
df2
# Out:
#          0
# 0  Primera
# 1  Segunda
# 2  Tercera
# 3   Cuarta
# 4   Quinta

# %%
data ={'Nombre': ['goku', 'gohan', 'picoro', 'vegeta', 'bulma'], 'Edad':[30, 22, 32, 30, 26], 'signo':['escorpio', 'cancer','sagitario', 'virgo', 'picis']}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad      signo
# 0    goku    30   escorpio
# 1   gohan    22     cancer
# 2  picoro    32  sagitario
# 3  vegeta    30      virgo
# 4   bulma    26      picis

# %%
print(df[['Edad']])
# Out:
#    Edad
# 0    30
# 1    22
# 2    32
# 3    30
# 4    26

# %%
data = pd.read_csv('canciones-2018_b2c776e4-1cce-40eb-b3e7-591ea6d29f83.csv')
data
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
data2 = pd.read_csv('salarios_dc1975e5-393f-4b89-9b04-a2b48ce17388.csv')
data2
# Out:
#     Aexperiencia  Salario
# 0           10.0    42500
# 1            8.0    36302
# 2            5.4    35000
# 3            2.5    18103
# 4            1.0    15000
# 5            8.0    37000
# 6            4.0    26300
# 7            6.0    35201
# 8            2.0    18302
# 9           10.0    42000
# 10           4.0    27000
# 11           7.0    35201
# 12           3.0    19201
# 13           5.0    28000
# 14           2.0    17000
# 15           5.0    33402
# 16           3.0    19000
# 17           2.0    18200
# 18           3.0    19000
# 19           2.0    17301
# 20           5.0    28000
# 21           3.4    20000
# 22           5.3    27900
# 23           2.1    17500
# 24           9.2    40000
# 25          10.0    42500
# 26           3.2    18300
# 27          10.0    40000
# 28           4.0    25000
# 29           1.0    15000

# %%
data.tail()
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
data2.shape
# Out:
# (30, 2)

# %%
data[[ 'acousticness', 'energy']].describe()
# Out:
#        acousticness      energy
# count    100.000000  100.000000
# mean       0.195701    0.659060
# std        0.220946    0.145067
# min        0.000282    0.296000
# 25%        0.040225    0.562000
# 50%        0.109000    0.678000
# 75%        0.247750    0.772250
# max        0.934000    0.909000

# %%
data2.sort_index(axis=1, ascending = True)
# Out:
#     Aexperiencia  Salario
# 0           10.0    42500
# 1            8.0    36302
# 2            5.4    35000
# 3            2.5    18103
# 4            1.0    15000
# 5            8.0    37000
# 6            4.0    26300
# 7            6.0    35201
# 8            2.0    18302
# 9           10.0    42000
# 10           4.0    27000
# 11           7.0    35201
# 12           3.0    19201
# 13           5.0    28000
# 14           2.0    17000
# 15           5.0    33402
# 16           3.0    19000
# 17           2.0    18200
# 18           3.0    19000
# 19           2.0    17301
# 20           5.0    28000
# 21           3.4    20000
# 22           5.3    27900
# 23           2.1    17500
# 24           9.2    40000
# 25          10.0    42500
# 26           3.2    18300
# 27          10.0    40000
# 28           4.0    25000
# 29           1.0    15000
